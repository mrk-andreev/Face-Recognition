# %%
# !pip install facenet_pytorch -i https://pypi.python.org/simple/
# Out:
# Looking in indexes: https://pypi.python.org/simple/
# Collecting facenet_pytorch
#   Downloading facenet_pytorch-2.5.3-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from facenet_pytorch) (1.23.4)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from facenet_pytorch) (2.28.1)
# Requirement already satisfied: torchvision in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from facenet_pytorch) (0.16.0)
# Requirement already satisfied: pillow in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from facenet_pytorch) (9.4.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->facenet_pytorch) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->facenet_pytorch) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->facenet_pytorch) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from requests->facenet_pytorch) (2022.12.7)
# Requirement already satisfied: torch==2.1.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from torchvision->facenet_pytorch) (2.1.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from torch==2.1.0->torchvision->facenet_pytorch) (3.8.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from torch==2.1.0->torchvision->facenet_pytorch) (4.7.1)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from torch==2.1.0->torchvision->facenet_pytorch) (1.12)
# Requirement already satisfied: networkx in /Users/iuliia/Library/Python/3.8/lib/python/site-packages (from torch==2.1.0->torchvision->facenet_pytorch) (2.8.8)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from torch==2.1.0->torchvision->facenet_pytorch) (3.1.2)
# Requirement already satisfied: fsspec in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from torch==2.1.0->torchvision->facenet_pytorch) (2023.9.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from jinja2->torch==2.1.0->torchvision->facenet_pytorch) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (from sympy->torch==2.1.0->torchvision->facenet_pytorch) (1.3.0)
# Installing collected packages: facenet_pytorch
# Successfully installed facenet_pytorch-2.5.3
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.2
# [notice] To update, run: pip install --upgrade pip

# %%
import os
import glob
import time
import torch
import cv2
from PIL import Image, ImageDraw
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from tqdm.notebook import tqdm
import skimage.io

# See github.com/timesler/facenet-pytorch:
from facenet_pytorch import MTCNN, InceptionResnetV1, extract_face

device = 'cuda:0' if torch.cuda.is_available() else 'cpu'
print(f'Running on device: {device}')
# Out:
# Running on device: cpu

# %%
# import ssl
# ssl._create_default_https_context = ssl._create_unverified_context

# %%
mtcnn = MTCNN(keep_all=True, device=device)

# %% [markdown]
# ### one face

# %%
image = cv2.imread('./data/test_img.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
img = Image.fromarray(image)
plt.imshow(img);

# %%
boxes, _ = mtcnn.detect(img)
boxes = boxes[0]

# %%
boxes
# Out:
# array([322.2824401855469, 78.70674133300781, 461.6004638671875,
#        276.2201843261719], dtype=object)

# %%
def create_corner_rect(bb, color='red'):
    bb = np.array(bb, dtype=np.float32)
    return plt.Rectangle((bb[0], bb[1]), bb[2]-bb[0], bb[3]-bb[1], color=color,
                         fill=False, lw=3)

def show_corner_bb(im, bb):
    plt.imshow(im)
    plt.gca().add_patch(create_corner_rect(bb))

# %%
show_corner_bb(img, boxes)

# %%
boxes = np.array(boxes, dtype=np.float32)
x1 = int(boxes[1])
x2 = int(boxes[3])
y1 = int(boxes[0])
y2 = int(boxes[2])
crop_img = image[x1:x2,y1:y2:]

# %%
plt.imshow(crop_img);

# %%
crop_img.shape
# Out:
# (198, 139, 3)

# %% [markdown]
# ### many faces

# %%
# put min_face_size=200 because else it found other faces on background
mtcnn = MTCNN(keep_all=True, device=device, min_face_size=200)

# %%
image = cv2.imread('./data/test_img2.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
img = Image.fromarray(image)
plt.imshow(img);

# %%
boxes, _ = mtcnn.detect(img)
boxes = np.array(boxes, dtype=np.float32)

# %%
if boxes.shape:
    crop_image_list = []
    for box in boxes:  
        x1 = int(box[1])
        x2 = int(box[3])
        y1 = int(box[0])
        y2 = int(box[2])
        crop_img = image[x1:x2,y1:y2:]
        crop_image_list.append(crop_img)

# %%
for crop_img in crop_image_list:
    print(crop_img.shape)
    plt.imshow(crop_img)
    plt.pause(0.001);
# Out:
# (228, 171, 3)
# (232, 169, 3)
# (210, 166, 3)
